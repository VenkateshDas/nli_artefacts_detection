# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.6 dill-0.3.7 huggingface-hub-0.18.0 multiprocess-0.70.15

# %%
import pandas as pd
import spacy
from ast import literal_eval
import nltk
nltk.download('punkt')
from collections import Counter
from tqdm import tqdm
import re
import string
from typing import Tuple
from datasets import load_dataset
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
years = [2018, 2019, 2020, 2021, 2022]

# %%
def read_data(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
def get_cwb_artefacts_imbalance(train_type, years):
    # get data
    contradiction_train_data_dict = {}
    cw_aug_data_need_dict = {}
    coliee_data_dict = {}
    for year in years:
        if train_type == "before":
            data_file_path = f"/content/drive/MyDrive/data/task 4/train/coliee_train_{year}.csv"
        elif train_type == "after":
            data_file_path = f"/content/drive/MyDrive/data/task 4/train/coliee_aug_train_{year}.csv"
        df = read_data(data_file_path)
        df['instance_type'] = "original"
        print(f"Year : {year}")

        contradiction_df = df[df['has_negation']==True]
        print(f"Number of total instances with contradiction : {contradiction_df.shape}")

        entailment_contradiction_df = contradiction_df[contradiction_df['labels']=="Y"]
        print(f"Number of entailment instances with contradiction : {entailment_contradiction_df.shape}")
        non_entailment_contradiction_df = contradiction_df[contradiction_df['labels']=="N"]
        print(f"Number of non-entailment instances with contradiction : {non_entailment_contradiction_df.shape}")

        diff = non_entailment_contradiction_df.shape[0] - entailment_contradiction_df.shape[0]
        print(f"Difference in contradiction instances between non-entailment and entailment labels: {diff}")
        coliee_data_dict[year] = df
        cw_aug_data_need_dict[year] = diff
        contradiction_train_data_dict[year] = contradiction_df

    return coliee_data_dict,cw_aug_data_need_dict, contradiction_train_data_dict


coliee_data_dict,cw_aug_data_need_dict, contradiction_train_data_dict = get_cwb_artefacts_imbalance("before", years)
# Out:
# Year : 2018
# Number of total instances with contradiction : (288, 16)
# Number of entailment instances with contradiction : (138, 16)
# Number of non-entailment instances with contradiction : (150, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 12
# Year : 2019
# Number of total instances with contradiction : (324, 16)
# Number of entailment instances with contradiction : (152, 16)
# Number of non-entailment instances with contradiction : (172, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 20
# Year : 2020
# Number of total instances with contradiction : (365, 16)
# Number of entailment instances with contradiction : (171, 16)
# Number of non-entailment instances with contradiction : (194, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 23
# Year : 2021
# Number of total instances with contradiction : (418, 16)
# Number of entailment instances with contradiction : (195, 16)
# Number of non-entailment instances with contradiction : (223, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 28
# Year : 2022
# Number of total instances with contradiction : (465, 16)
# Number of entailment instances with contradiction : (218, 16)
# Number of non-entailment instances with contradiction : (247, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 29

# %%
cw_aug_data_need_dict
# Out:
# {2018: 12, 2019: 20, 2020: 23, 2021: 28, 2022: 29}

# %%
def get_wob_artefacts_imbalance(train_type, years):
    # get data
    print(years)
    wo_aug_data_need_dict = {}
    for year in years:
        print(year)
        if train_type == "before":
            data_file_path = f"/content/drive/MyDrive/data/task 4/train/coliee_train_{year}.csv"
        elif train_type == "after":
            data_file_path = f"/content/drive/MyDrive/data/task 4/train/coliee_aug_train_{year}.csv"

        df = read_data(data_file_path)
        print(f"Year : {year}")

        df['percent_overlap'] = (df['overlap'] / df['hyp_length']) * 100

        wob_df = df[(df['is_word_overlap']==True) & (df['has_negation']==False) & (df['is_subsequence_heuristic']==False)]
        print(f"Number of total instances with Word Overlap : {wob_df.shape}")

        # More than 50%

        entailment_wob_df = wob_df[(wob_df['labels']=="Y")  & (wob_df['percent_overlap']>=50)]
        print(f"Number of entailment instances with Word Overlaps : {entailment_wob_df.shape}")
        non_entailment_wob_df = wob_df[(wob_df['labels']=="N")  & (wob_df['percent_overlap']>=50)]
        print(f"Number of non-entailment instances with Word Overlaps : {non_entailment_wob_df.shape}")

        diff = entailment_wob_df.shape[0] - non_entailment_wob_df.shape[0]
        print(f"Difference in word overlap instances between entailment and non-entailment labels above 50%: {diff}")
        wo_aug_data_need_dict[year] = diff

        # Less than 50 %

        # ls_entailment_wob_df = wob_df[(wob_df['labels']=="Y")  & (wob_df['percent_overlap']<50)]
        # print(f"Number of entailment instances with Word Overlaps : {ls_entailment_wob_df.shape}")
        # ls_non_entailment_wob_df = wob_df[(wob_df['labels']=="N")  & (wob_df['percent_overlap']<50)]
        # print(f"Number of non-entailment instances with Word Overlaps : {ls_non_entailment_wob_df.shape}")

        # ls_diff = ls_entailment_wob_df.shape[0] - ls_non_entailment_wob_df.shape[0]
        # print(f"Difference in word overlap instances between entailment and non-entailment labels below 50%: {ls_diff}")

    return wo_aug_data_need_dict

wo_aug_data_need_dict = get_wob_artefacts_imbalance(train_type="before", years=years)
# Out:
# [2018, 2019, 2020, 2021, 2022]
# 2018
# Year : 2018
# Number of total instances with Word Overlap : (277, 16)
# Number of entailment instances with Word Overlaps : (109, 16)
# Number of non-entailment instances with Word Overlaps : (70, 16)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 39
# 2019
# Year : 2019
# Number of total instances with Word Overlap : (298, 16)
# Number of entailment instances with Word Overlaps : (117, 16)
# Number of non-entailment instances with Word Overlaps : (79, 16)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 38
# 2020
# Year : 2020
# Number of total instances with Word Overlap : (327, 16)
# Number of entailment instances with Word Overlaps : (129, 16)
# Number of non-entailment instances with Word Overlaps : (87, 16)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 42
# 2021
# Year : 2021
# Number of total instances with Word Overlap : (384, 16)
# Number of entailment instances with Word Overlaps : (150, 16)
# Number of non-entailment instances with Word Overlaps : (101, 16)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 49
# 2022
# Year : 2022
# Number of total instances with Word Overlap : (414, 16)
# Number of entailment instances with Word Overlaps : (157, 16)
# Number of non-entailment instances with Word Overlaps : (118, 16)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 39

# %%
wo_aug_data_need_dict
# Out:
# {2018: 39, 2019: 38, 2020: 42, 2021: 49, 2022: 39}

# %%
cw_aug_df = read_data("/content/drive/MyDrive/data/task 4/train/data_aug_contradiction_instances.csv")
wo_aug_df = read_data("/content/drive/MyDrive/data/task 4/train/data_aug_word_overlap_instances.csv")

# %%
cw_aug_df = cw_aug_df[['id','label','premise','hypothesis','labels']]
wo_aug_df = wo_aug_df[['id','label','premise','hypothesis','labels']]

# %%
cw_aug_df.columns
# Out:
# Index(['id', 'label', 'premise', 'hypothesis', 'labels'], dtype='object')

# %%
# prepare the aug_df with the extra columns needed for merging
# addition of features
# sentence length, number of word overlaps, is there word overlap, is there a negation word, is there a subsequence heuristic

# List of negation words
negation_words = ["not", "no", "n't", "none", "neither", "never", "nobody", "nothing", "nowhere", "hardly", "scarcely", "barely", "rarely", "seldom"]


def extract_negation(tokens):
    negations = [token for token in tokens if token in negation_words]
    return negations

def calculate_overlap(premise, hypothesis):
    """
    This function takes in two sentences as arguments (the premise and the hypothesis), tokenizes them,
    and calculates the count of words that overlap between them if the overlap is high (above the threshold).
    The threshold is defined as a ratio of the total words in both sentences.
    """

    # Tokenize the sentences
    premise_tokens = nltk.word_tokenize(premise.lower())
    hypothesis_tokens = nltk.word_tokenize(hypothesis.lower())

    # Count the words in each sentence
    premise_counter = Counter(premise_tokens)
    hypothesis_counter = Counter(hypothesis_tokens)

    # Calculate the overlap using the intersection of the two Counters
    overlap_counter = premise_counter & hypothesis_counter
    overlap = sum(overlap_counter.values())

    return overlap

def detect_word_overlap_bias(df):
    """
    This function takes in a dataframe with 'premise', 'hypothesis', and 'label' columns,
    calculates the number of overlapping words for each row and adds this as a new 'overlap' column,
    then calculates the average overlap for 'entailment' cases and for 'non-entailment' cases,
    and compares the two.
    It also counts the number of instances in the 'entailment' and 'non-entailment' cases
    where the overlap is above a given threshold.
    """

    # Calculate overlap for each row and add it as a new 'overlap' column
    df['overlap'] = df.apply(lambda row: calculate_overlap(row['premise'], row['hypothesis']), axis=1)

    # create a new column to indicate if there is word overlap
    df['is_word_overlap'] = df['overlap'].apply(lambda x: True if x > 0 else False)

    return df

def remove_punctuation(input_string):
    translator = str.maketrans('', '', string.punctuation)
    return input_string.translate(translator)

def detect_subsequence(premise: str, hypothesis: str) -> Tuple[str, bool]:
    premise_words = remove_punctuation(premise.lower())
    hypothesis_words = remove_punctuation(hypothesis.lower())
    # Add word boundaries to the hypothesis
    hypothesis_words = r"\b" + hypothesis_words + r"\b"
    if re.search(hypothesis_words, premise_words):
        return (hypothesis, True)
    else:
        return ("", False)

def add_features(df):
    df['hyp_tokens'] = df['hypothesis'].apply(lambda x: nltk.word_tokenize(x.lower()))
    df['hyp_length'] = df['hyp_tokens'].apply(lambda x: len(x))
    df['prem_tokens'] = df['premise'].apply(lambda x: nltk.word_tokenize(x.lower()))
    df['prem_length'] = df['prem_tokens'].apply(lambda x: len(x))
    df = detect_word_overlap_bias(df)
    df['negations'] = df['hyp_tokens'].apply(lambda x: extract_negation(x))
    df['has_negation'] = df['negations'].apply(lambda x: True if len(x) > 0 else False)
    df['detected_subsequence'], df['is_subsequence_heuristic'] = zip(*df.apply(lambda row: detect_subsequence(row['premise'], row['hypothesis']), axis=1))

    return df

# %%
cw_aug_df = add_features(cw_aug_df)
wo_aug_df = add_features(wo_aug_df)

# %%
cw_aug_df
# Out:
#                 id  label                                            premise  \
# 0    CW-AD-H18-2-4      1  Article 702\n(1) If a manager has incurred ben...
# 1   CW-AD-H18-23-I      1  Article 537\n(1) If one of the parties promise...
# 2   CW-AD-H18-26-1      1  Article 255\nIf one of co-owners waives intere...
# 3   CW-AD-H19-11-3      1  Article 177\nAcquisitions of, losses of and ch...
# 4   CW-AD-H19-12-4      1  Article 343\nA thing that cannot be transferre...
# 5   CW-AD-H20-23-5      1  Article 588\nIf any person has an obligation t...
# 6   CW-AD-H21-19-A      1  Article 447\n(1) The guarantee obligation incl...
# 7   CW-AD-H22-15-U      1  Article 677\nA partner's creditor may not exer...
# 8   CW-AD-H22-21-4      1  Article 492\nUpon tendering the performance, t...
# 9    CW-AD-H23-9-2      1  Article 192\nA person that commences the posse...
# 10   CW-AD-H24-4-O      1  Article 105\nA legal representative may appoin...
# 11  CW-AD-H24-11-4      1  Article 249\nEach co-owner may use the entire ...
# 12  CW-AD-H24-17-1      1  Article 333\nStatutory liens may not be exerci...
# 13   CW-AD-H25-8-1      1  Article 192\nA person that commences the posse...
# 14  CW-AD-H25-29-O      1  Article 659\nA gratuitous bailee bears a duty ...
# 15  CW-AD-H26-10-2      1  Article 200\n(1) If a possessor is forcibly di...
# 16  CW-AD-H26-13-G      1  Article 300\nThe exercise of a right of retent...
# 17  CW-AD-H26-16-E      1  Article 536\n(1) If the performance of an obli...
# 18  CW-AD-H27-22-3      1  Article 632\nA contract for work become effect...
# 19  CW-AD-H27-36-I      1  Article 405\nIf the payment of interest corres...
# 20   CW-AD-H29-4-A      1  Article 94\n(1) A false manifestation of inten...
# 21   CW-AD-H30-1-A      1  Article 3\n(1) The enjoyment of private rights...
# 22   CW-AD-H30-7-A      1  Article 176\nThe creation and transfer of a re...
# 23   CW-AD-H30-8-I      1  Article 180\nPossessory rights are acquired by...
# 24   CW-AD-H30-9-U      1  Article 270\nA farming right holder has the ri...
# 25  CW-AD-H30-11-U      1  Article 244\nIf the distinction of principal a...
# 26  CW-AD-H30-24-U      1  Article 593\nA loan for use becomes effective ...
# 27  CW-AD-H30-28-U      1  Article 702\n(1) If a manager has incurred ben...
# 28   CW-AD-R01-8-A      1  Article 242\nThe owner of immovables acquires ...
# 29   CW-AD-R1-21-O      1  Article 520\nIf a claim and obligation becomes...
# 30   CW-AD-R1-24-A      1  Article 536\n(1) If the performance of an obli...
# 31   CW-AD-R1-24-I      1  Article 541\nIf one of the parties does not pe...
# 32   CW-AD-R1-24-E      1  Article 533\nA party to a bilateral contract m...
# 33   CW-AD-R02-9-O      1  Article 201 (1) An action for maintenance of p...
#
#                                            hypothesis labels  \
# 0   "When someone fixes a neighbor's fence affecte...      Y
# 1   "In a scenario where individual A transfers a ...      Y
# 2   "If one co-owner of a property, shared equally...      Y
# 3   "If A purchases a registered building from B, ...      Y
# 4   "If a commitment is established to create a pl...      Y
# 5   A quasi-loan contract shall not become effecti...      Y
# 6   "In instances where a contract cancellation re...      Y
# 7   A debtor to a partnership is not able to set o...      Y
# 8   "When the person obliged to pay a financial ob...      Y
# 9   Provisions for immediate acquisition are not a...      Y
# 10  "An agent who has been privately assigned isn'...      Y
# 11  "Even though the land used for farming is unde...      Y
# 12  "Even when an agreement exists between the ori...      Y
# 13  "Even when an individual makes an agreement fo...      Y
# 14  When a merchant accepts a deposit as part of t...      Y
# 15  Even though University A's library owns book '...      Y
# 16  "If a contractor withholds the delivery of the...      Y
# 17  "If a particular type of wine is the object in...      Y
# 18  "Even if a building, that is being constructed...      Y
# 19  "When the merchant has an obligation to delive...      Y
# 20  "If A, the owner of the land 'X', has particip...      Y
# 21  "A deceased person's gift cannot be bestowed u...      Y
# 22  "In their litigation case, B must substantiate...      Y
# 23  A's minor child B, who resides with A in build...      Y
# 24  "It might not be possible to set up a free emp...      Y
# 25  "When a ship owned by A and an engine owned by...      Y
# 26  "When a property owner, A, and B enter into a ...      Y
# 27  "When B took it upon himself to mend a portion...      Y
# 28  "If a person has sown seeds on a land where th...      Y
# 29  "Should the tenant (B) remain in possession of...      Y
# 30  "When parties (A) and (B) established a deal f...      Y
# 31  (A) and (B) concurred on a deal for (A) to sel...      Y
# 32  "(A) and (B) had a mutual agreement for (A) to...      Y
# 33  "If A possessed a plot in a vacation homes reg...      Y
#
#                                            hyp_tokens  hyp_length  \
# 0   [``, when, someone, fixes, a, neighbor, 's, fe...          52
# 1   [``, in, a, scenario, where, individual, a, tr...         106
# 2   [``, if, one, co-owner, of, a, property, ,, sh...          38
# 3   [``, if, a, purchases, a, registered, building...          52
# 4   [``, if, a, commitment, is, established, to, c...          45
# 5   [a, quasi-loan, contract, shall, not, become, ...          21
# 6   [``, in, instances, where, a, contract, cancel...          86
# 7   [a, debtor, to, a, partnership, is, not, able,...          20
# 8   [``, when, the, person, obliged, to, pay, a, f...          42
# 9   [provisions, for, immediate, acquisition, are,...          28
# 10  [``, an, agent, who, has, been, privately, ass...          63
# 11  [``, even, though, the, land, used, for, farmi...          82
# 12  [``, even, when, an, agreement, exists, betwee...          63
# 13  [``, even, when, an, individual, makes, an, ag...          63
# 14  [when, a, merchant, accepts, a, deposit, as, p...          38
# 15  [even, though, university, a, 's, library, own...          96
# 16  [``, if, a, contractor, withholds, the, delive...          44
# 17  [``, if, a, particular, type, of, wine, is, th...          79
# 18  [``, even, if, a, building, ,, that, is, being...          56
# 19  [``, when, the, merchant, has, an, obligation,...          57
# 20  [``, if, a, ,, the, owner, of, the, land, ', x...          70
# 21  [``, a, deceased, person, 's, gift, can, not, ...          16
# 22  [``, in, their, litigation, case, ,, b, must, ...         130
# 23  [a, 's, minor, child, b, ,, who, resides, with...          27
# 24  [``, it, might, not, be, possible, to, set, up...          14
# 25  [``, when, a, ship, owned, by, a, and, an, eng...          69
# 26  [``, when, a, property, owner, ,, a, ,, and, b...          73
# 27  [``, when, b, took, it, upon, himself, to, men...          60
# 28  [``, if, a, person, has, sown, seeds, on, a, l...          39
# 29  [``, should, the, tenant, (, b, ), remain, in,...          99
# 30  [``, when, parties, (, a, ), and, (, b, ), est...          95
# 31  [(, a, ), and, (, b, ), concurred, on, a, deal...         118
# 32  [``, (, a, ), and, (, b, ), had, a, mutual, ag...         118
# 33  [``, if, a, possessed, a, plot, in, a, vacatio...          69
#
#                                           prem_tokens  prem_length  overlap  \
# 0   [article, 702, (, 1, ), if, a, manager, has, i...           98       18
# 1   [article, 537, (, 1, ), if, one, of, the, part...          120       32
# 2   [article, 255, if, one, of, co-owners, waives,...           22        6
# 3   [article, 177, acquisitions, of, ,, losses, of...           54       16
# 4   [article, 343, a, thing, that, can, not, be, t...           22       11
# 5   [article, 588, if, any, person, has, an, oblig...           48        8
# 6   [article, 447, (, 1, ), the, guarantee, obliga...           62       21
# 7   [article, 677, a, partner, 's, creditor, may, ...           19        5
# 8   [article, 492, upon, tendering, the, performan...           26        9
# 9   [article, 192, a, person, that, commences, the...           41        4
# 10  [article, 105, a, legal, representative, may, ...           47       19
# 11  [article, 249, each, co-owner, may, use, the, ...           19        4
# 12  [article, 333, statutory, liens, may, not, be,...           31       13
# 13  [article, 192, a, person, that, commences, the...           41       14
# 14  [article, 659, a, gratuitous, bailee, bears, a...           30        9
# 15  [article, 200, (, 1, ), if, a, possessor, is, ...           87       21
# 16  [article, 300, the, exercise, of, a, right, of...           20        9
# 17  [article, 536, (, 1, ), if, the, performance, ...           84       29
# 18  [article, 632, a, contract, for, work, become,...           32       12
# 19  [article, 405, if, the, payment, of, interest,...           42       17
# 20  [article, 94, (, 1, ), a, false, manifestation...           52       15
# 21  [article, 3, (, 1, ), the, enjoyment, of, priv...           35        1
# 22  [article, 176, the, creation, and, transfer, o...           83       32
# 23  [article, 180, possessory, rights, are, acquir...           22        7
# 24  [article, 270, a, farming, right, holder, has,...           25        2
# 25  [article, 244, if, the, distinction, of, princ...           44       13
# 26  [article, 593, a, loan, for, use, becomes, eff...           48       16
# 27  [article, 702, (, 1, ), if, a, manager, has, i...           98       20
# 28  [article, 242, the, owner, of, immovables, acq...           44       12
# 29  [article, 520, if, a, claim, and, obligation, ...           44       19
# 30  [article, 536, (, 1, ), if, the, performance, ...           84       22
# 31  [article, 541, if, one, of, the, parties, does...          129       31
# 32  [article, 533, a, party, to, a, bilateral, con...           74       21
# 33  [article, 201, (, 1, ), an, action, for, maint...           70       20
#
#     is_word_overlap       negations  has_negation detected_subsequence  \
# 0              True           [not]          True
# 1              True           [not]          True
# 2              True            [no]          True
# 3              True           [not]          True
# 4              True           [not]          True
# 5              True      [not, not]          True
# 6              True           [not]          True
# 7              True           [not]          True
# 8              True           [not]          True
# 9              True           [not]          True
# 10             True  [n't, neither]          True
# 11             True           [not]          True
# 12             True           [not]          True
# 13             True           [not]          True
# 14             True           [not]          True
# 15             True           [not]          True
# 16             True           [n't]          True
# 17             True           [not]          True
# 18             True      [not, not]          True
# 19             True           [not]          True
# 20             True           [not]          True
# 21             True           [not]          True
# 22             True           [not]          True
# 23             True           [not]          True
# 24             True           [not]          True
# 25             True      [not, not]          True
# 26             True       [no, not]          True
# 27             True           [not]          True
# 28             True            [no]          True
# 29             True           [not]          True
# 30             True           [not]          True
# 31             True           [not]          True
# 32             True           [not]          True
# 33             True           [not]          True
#
#     is_subsequence_heuristic
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                     False
# 11                     False
# 12                     False
# 13                     False
# 14                     False
# 15                     False
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                     False
# 29                     False
# 30                     False
# 31                     False
# 32                     False
# 33                     False

# %%
wo_aug_df
# Out:
#                 id  label                                            premise  \
# 0   WO-AD-H18-28-4      0  Article 465-3\n(1) If a contract for revolving...
# 1   WO-AD-H19-12-1      0  Article 350\nThe provisions of Articles 296 th...
# 2   WO-AD-H19-16-2      0  Article 387\n(1) A registered lease may be dul...
# 3   WO-AD-H22-26-U      0  Article 646\n(1) A mandatary must deliver to t...
# 4   WO-AD-H23-11-O      0  Article 702\n(1) If a manager has incurred ben...
# 5    WO-AD-H24-8-5      0  Article 424\n(1) An obligee may demand the cou...
# 6   WO-AD-H24-20-I      0  Article 465-3\n(1) If a contract for revolving...
# 7   WO-AD-H24-27-O      0  Article 637\n(1) In the case prescribed in the...
# 8   WO-AD-H25-13-3      0  Article 366\n(1) A pledgee may directly collec...
# 9   WO-AD-H25-16-4      0  Article 370\nA mortgage extends to the things ...
# 10  WO-AD-H25-23-U      0  Article 506\n(1) Set-offs are effected through...
# 11  WO-AD-H26-12-I      0  Article 233\n(1) If a tree or bamboo branch fr...
# 12  WO-AD-H26-13-I      0  Article 304\n(1) A statutory lien may also be ...
# 13  WO-AD-H26-17-C      0  Article 424\n(1) An obligee may demand the cou...
# 14  WO-AD-H26-23-A      0  Article 574\nIf price is to be paid simultaneo...
# 15  WO-AD-H26-36-I      0  Article 391\nIf a third party acquirer of a mo...
# 16  WO-AD-H27-12-E      0  Article 334\nIf there is conflict between a st...
# 17  WO-AD-H27-27-O      0  Article 637\n(1) In the case prescribed in the...
# 18  WO-AD-H27-28-A      0  Article 711\nA person that has taken the life ...
# 19  WO-AD-H27-36-U      0  Article 462\n(1) The provisions of Article 459...
# 20  WO-AD-H28-11-1      0  Article 177\nAcquisitions of, losses of and ch...
# 21  WO-AD-H28-11-5      0  Article 334\nIf there is conflict between a st...
# 22  WO-AD-H28-14-3      0  Article 378\nIf a third party that purchases t...
# 23  WO-AD-H28-16-1      0  Article 398-12\n(1) Before the principal is cr...
# 24  WO-AD-H28-16-2      0  Article 398-4\n(1) The scope of the claims to ...
# 25   WO-AD-H29-3-A      0  Article 31\nA person subject to a declaration ...
# 26  WO-AD-H29-13-A      0  Article 329\n(1) If there are competing genera...
# 27  WO-AD-H29-26-5      0  Article 577\n(1) If a mortgage that does not c...
# 28   WO-AD-H30-8-A      0  Article 201\n(1) An action for maintenance of ...
# 29  WO-AD-H30-15-A      0  Article 398-4\n(1) The scope of the claims to ...
# 30  WO-AD-H30-29-U      0  Article 717\n(1) If a defect in the installati...
# 31   WO-AD-R01-1-O      0  Article 124\n(1) The ratification of a voidabl...
# 32   WO-AD-R01-4-U      0  Article 133\n(1) A juridical act subject to an...
# 33   WO-AD-R01-4-O      0  Article 134\nA juridical act subject to a cond...
# 34   WO-AD-R01-9-U      0  Article 233\n(1) If a tree or bamboo branch fr...
# 35   WO-AD-R1-17-I      0  Article 450\n(1) If an obligor has the obligat...
# 36   WO-AD-R1-21-E      0  Article 518\n(1) To the extent of the amount o...
# 37  WO-AD-R01-36-I      0  Article 663\n(1) If the parties have not speci...
# 38  WO-AD-R01-37-A      0  Article 400\nIf the subject matter of a claim ...
# 39   WO-AD-R02-1-A      0  Article 15 (1) The family court may decide to ...
# 40   WO-AD-R02-1-I      0  Article 15 (1) The family court may decide to ...
# 41   WO-AD-R02-1-U      0  Article 18 (1) If the grounds prescribed in th...
# 42   WO-AD-R02-3-I      0  Article 120 (1) An act that is voidable on the...
# 43   WO-AD-R02-5-E      0  Article 169 (1) The period of prescription of ...
# 44  WO-AD-R02-16-A      0  Article 424-7 (1) In an action concerning dema...
# 45  WO-AD-R02-23-I      0  Article 484 (1) Unless a particular intention ...
# 46  WO-AD-R02-25-I      0  Article 606 (1) A lessor assumes an obligation...
# 47  WO-AD-R02-27-A      0  Article 676 (2) A partner may not independentl...
# 48  WO-AD-R02-27-I      0  Article 670 (1) The partnership business is de...
#
#                                            hypothesis labels  \
# 0   "If the principal crystallization date for a c...      N
# 1   A holder of a statutory lien, a pledge, or a m...      N
# 2   A registered lease can be asserted against a m...      N
# 3   If the mandatary has received monies and other...      N
# 4   Even if the manager has gone against the princ...      N
# 5   An obligee (B) against (A) may demand the cour...      N
# 6   If the day three years have passed from the da...      N
# 7   Where the contractor delivers the subject matt...      N
# 8   If monies are the subject matter of a pledged ...      N
# 9   A mortgage shall extend to the buildings on th...      N
# 10  "It's permissible to append a condition to the...      N
# 11  If a tree or bamboo branch from neighboring la...      N
# 12  A holder of a right of retention can exercise ...      N
# 13  To demand the Rescission of Fraudulent Act, it...      N
# 14  Even if the delivery of the subject matter of ...      N
# 15  "In cases where a third party acquirer of Mort...      N
# 16  In cases where a pledge is established concern...      N
# 17  If the party ordering work discovers any defec...      N
# 18  A person that has taken the life of another is...      N
# 19  "If an individual, who has given guarantee wit...      N
# 20  The order in which special statutory liens, pl...      N
# 21  The pledge of movables is subordinate to the s...      N
# 22  If a mortgagee asks a third party who buys the...      N
# 23  Before the principal is determined, a revolvin...      N
# 24  When altering the scope of claims to be secure...      N
# 25  If a vessel on which A was aboard sinks, and a...      N
# 26  Statutory liens on expenses for the common ben...      N
# 27  If a mortgage is registered on the immovable p...      N
# 28  "During the disturbance, actions for maintenan...      N
# 29  In order to modify obligors before the princip...      N
# 30  If there is a defect in the installation or pr...      N
# 31  The period of time within which an adult ward ...      N
# 32  A juridical act that is subject to an impossib...      N
# 33  A juridical act that is subject to a condition...      N
# 34  If a tree or bamboo branch from a neighboring ...      N
# 35  A person who can act needs to be the guarantor...      N
# 36  To the extent of the amount of the obligation ...      N
# 37  If the depositor dies and the timing of the re...      N
# 38  In cases where the subject of a claim is the d...      N
# 39  The family court is empowered to begin assista...      N
# 40  The initiation of assistance upon the request ...      N
# 41  If the grounds of commencement of assistance c...      N
# 42  If a person (A) has the right to rescind an ac...      N
# 43  If a right that has a prescription period shor...      N
# 44  In the event that an obligee (C) initiates a l...      N
# 45  Unless a specific intention is manifested with...      N
# 46  A lessor is obligated to make necessary repair...      N
# 47  "A partner is entitled to exercise the rights ...      N
# 48  "The partnership business is decided by the ma...      N
#
#                                            hyp_tokens  hyp_length  \
# 0   [``, if, the, principal, crystallization, date...          36
# 1   [a, holder, of, a, statutory, lien, ,, a, pled...          46
# 2   [a, registered, lease, can, be, asserted, agai...          38
# 3   [if, the, mandatary, has, received, monies, an...          26
# 4   [even, if, the, manager, has, gone, against, t...          30
# 5   [an, obligee, (, b, ), against, (, a, ), may, ...          57
# 6   [if, the, day, three, years, have, passed, fro...          39
# 7   [where, the, contractor, delivers, the, subjec...          40
# 8   [if, monies, are, the, subject, matter, of, a,...          35
# 9   [a, mortgage, shall, extend, to, the, building...          17
# 10  [``, it, 's, permissible, to, append, a, condi...          15
# 11  [if, a, tree, or, bamboo, branch, from, neighb...          38
# 12  [a, holder, of, a, right, of, retention, can, ...          34
# 13  [to, demand, the, rescission, of, fraudulent, ...          29
# 14  [even, if, the, delivery, of, the, subject, ma...          30
# 15  [``, in, cases, where, a, third, party, acquir...          51
# 16  [in, cases, where, a, pledge, is, established,...          35
# 17  [if, the, party, ordering, work, discovers, an...          34
# 18  [a, person, that, has, taken, the, life, of, a...          33
# 19  [``, if, an, individual, ,, who, has, given, g...          44
# 20  [the, order, in, which, special, statutory, li...          26
# 21  [the, pledge, of, movables, is, subordinate, t...          13
# 22  [if, a, mortgagee, asks, a, third, party, who,...          38
# 23  [before, the, principal, is, determined, ,, a,...          35
# 24  [when, altering, the, scope, of, claims, to, b...          30
# 25  [if, a, vessel, on, which, a, was, aboard, sin...          37
# 26  [statutory, liens, on, expenses, for, the, com...          16
# 27  [if, a, mortgage, is, registered, on, the, imm...          40
# 28  [``, during, the, disturbance, ,, actions, for...          15
# 29  [in, order, to, modify, obligors, before, the,...          20
# 30  [if, there, is, a, defect, in, the, installati...          50
# 31  [the, period, of, time, within, which, an, adu...          28
# 32  [a, juridical, act, that, is, subject, to, an,...          16
# 33  [a, juridical, act, that, is, subject, to, a, ...          26
# 34  [if, a, tree, or, bamboo, branch, from, a, nei...          28
# 35  [a, person, who, can, act, needs, to, be, the,...          20
# 36  [to, the, extent, of, the, amount, of, the, ob...          49
# 37  [if, the, depositor, dies, and, the, timing, o...          25
# 38  [in, cases, where, the, subject, of, a, claim,...          55
# 39  [the, family, court, is, empowered, to, begin,...          30
# 40  [the, initiation, of, assistance, upon, the, r...          30
# 41  [if, the, grounds, of, commencement, of, assis...          32
# 42  [if, a, person, (, a, ), has, the, right, to, ...          42
# 43  [if, a, right, that, has, a, prescription, per...          33
# 44  [in, the, event, that, an, obligee, (, c, ), i...          35
# 45  [unless, a, specific, intention, is, manifeste...          53
# 46  [a, lessor, is, obligated, to, make, necessary...          34
# 47  [``, a, partner, is, entitled, to, exercise, t...          31
# 48  [``, the, partnership, business, is, decided, ...          27
#
#                                           prem_tokens  prem_length  overlap  \
# 0   [article, 465-3, (, 1, ), if, a, contract, for...          458       31
# 1   [article, 350, the, provisions, of, articles, ...          142       32
# 2   [article, 387, (, 1, ), a, registered, lease, ...           94       25
# 3   [article, 646, (, 1, ), a, mandatary, must, de...           64       19
# 4   [article, 702, (, 1, ), if, a, manager, has, i...           98       20
# 5   [article, 424, (, 1, ), an, obligee, may, dema...          179       39
# 6   [article, 465-3, (, 1, ), if, a, contract, for...          481       32
# 7   [article, 637, (, 1, ), in, the, case, prescri...          152       34
# 8   [article, 366, (, 1, ), a, pledgee, may, direc...          152       31
# 9   [article, 370, a, mortgage, extends, to, the, ...           87       12
# 10  [article, 506, (, 1, ), set-offs, are, effecte...           71        9
# 11  [article, 233, (, 1, ), if, a, tree, or, bambo...           61       28
# 12  [article, 304, (, 1, ), a, statutory, lien, ma...          103       23
# 13  [article, 424, (, 1, ), an, obligee, may, dema...          179       22
# 14  [article, 574, if, price, is, to, be, paid, si...          121       24
# 15  [article, 391, if, a, third, party, acquirer, ...          230       35
# 16  [article, 334, if, there, is, conflict, betwee...          289       26
# 17  [article, 637, (, 1, ), in, the, case, prescri...          152       22
# 18  [article, 711, a, person, that, has, taken, th...           44       24
# 19  [article, 462, (, 1, ), the, provisions, of, a...          494       33
# 20  [article, 177, acquisitions, of, ,, losses, of...          284       20
# 21  [article, 334, if, there, is, conflict, betwee...          289       12
# 22  [article, 378, if, a, third, party, that, purc...           45       25
# 23  [article, 398-12, (, 1, ), before, the, princi...          191       28
# 24  [article, 398-4, (, 1, ), the, scope, of, the,...          103       24
# 25  [article, 31, a, person, subject, to, a, decla...          184       25
# 26  [article, 329, (, 1, ), if, there, are, compet...           84       14
# 27  [article, 577, (, 1, ), if, a, mortgage, that,...          110       27
# 28  [article, 201, (, 1, ), an, action, for, maint...          144       10
# 29  [article, 398-4, (, 1, ), the, scope, of, the,...          103       17
# 30  [article, 717, (, 1, ), if, a, defect, in, the...          138       42
# 31  [article, 124, (, 1, ), the, ratification, of,...          185       20
# 32  [article, 133, (, 1, ), a, juridical, act, sub...           35       12
# 33  [article, 134, a, juridical, act, subject, to,...           25       16
# 34  [article, 233, (, 1, ), if, a, tree, or, bambo...           61       20
# 35  [article, 450, (, 1, ), if, an, obligor, has, ...          114       15
# 36  [article, 518, (, 1, ), to, the, extent, of, t...          137       39
# 37  [article, 663, (, 1, ), if, the, parties, have...           66       19
# 38  [article, 400, if, the, subject, matter, of, a...          178       43
# 39  [article, 15, (, 1, ), the, family, court, may...          214       19
# 40  [article, 15, (, 1, ), the, family, court, may...          145       20
# 41  [article, 18, (, 1, ), if, the, grounds, presc...          127       23
# 42  [article, 120, (, 1, ), an, act, that, is, voi...          128       27
# 43  [article, 169, (, 1, ), the, period, of, presc...           79       27
# 44  [article, 424-7, (, 1, ), in, an, action, conc...          124       24
# 45  [article, 484, (, 1, ), unless, a, particular,...           64       38
# 46  [article, 606, (, 1, ), a, lessor, assumes, an...           46       21
# 47  [article, 676, (, 2, ), a, partner, may, not, ...           35       19
# 48  [article, 670, (, 1, ), the, partnership, busi...          126       25
#
#     is_word_overlap negations  has_negation detected_subsequence  \
# 0              True        []         False
# 1              True        []         False
# 2              True        []         False
# 3              True        []         False
# 4              True        []         False
# 5              True        []         False
# 6              True        []         False
# 7              True        []         False
# 8              True        []         False
# 9              True        []         False
# 10             True        []         False
# 11             True        []         False
# 12             True        []         False
# 13             True        []         False
# 14             True        []         False
# 15             True        []         False
# 16             True        []         False
# 17             True        []         False
# 18             True        []         False
# 19             True        []         False
# 20             True        []         False
# 21             True        []         False
# 22             True        []         False
# 23             True        []         False
# 24             True        []         False
# 25             True        []         False
# 26             True        []         False
# 27             True        []         False
# 28             True        []         False
# 29             True        []         False
# 30             True        []         False
# 31             True        []         False
# 32             True        []         False
# 33             True        []         False
# 34             True        []         False
# 35             True        []         False
# 36             True        []         False
# 37             True        []         False
# 38             True        []         False
# 39             True        []         False
# 40             True        []         False
# 41             True        []         False
# 42             True        []         False
# 43             True        []         False
# 44             True        []         False
# 45             True        []         False
# 46             True        []         False
# 47             True        []         False
# 48             True        []         False
#
#     is_subsequence_heuristic
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                     False
# 11                     False
# 12                     False
# 13                     False
# 14                     False
# 15                     False
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                     False
# 29                     False
# 30                     False
# 31                     False
# 32                     False
# 33                     False
# 34                     False
# 35                     False
# 36                     False
# 37                     False
# 38                     False
# 39                     False
# 40                     False
# 41                     False
# 42                     False
# 43                     False
# 44                     False
# 45                     False
# 46                     False
# 47                     False
# 48                     False

# %%
def augment_train_data(train_data, aug_data, data_needed):
    aug_data = aug_data[:data_needed]
    concat_data = pd.concat([train_data, aug_data])
    return concat_data

# %%
coliee_data_dict[2022]
# Out:
#            id  label                                            premise  \
# 0     H18-1-1      1  Article 572\nEven if the seller makes a specia...
# 1     H18-1-2      0  Article 565\nThe provisions of the preceding t...
# 2     H18-1-3      0  Article 568\n(1) The successful bidder at an a...
# 3     H18-2-1      1  Article 697\n(1) A person that has begun to ma...
# 4     H18-2-2      1  Article 698\nIf a manager engages in benevolen...
# ..        ...    ...                                                ...
# 882  R02-36-I      0  Article 153 (1) The postponement of the expiry...
# 883  R02-36-U      1  Article 187 (1) A successor to a possessor may...
# 884  R02-36-E      0  Article 254 A claim that one of the co-owners ...
# 885  R02-37-A      1  Article 406 If the subject matter of the claim...
# 886  R02-37-I      1  Article 540 (1) If one of the parties has the ...
#
#                                             hypothesis labels  \
# 0    A special provision that releases warranty can...      Y
# 1    There is a limitation period on pursuance of w...      N
# 2    A compulsory auction is also a sale, so warran...      N
# 3    In cases where a person plans to prevent crime...      Y
# 4    In cases where an individual rescues another p...      Y
# ..                                                 ...    ...
# 882  The postponement of expiry of prescription per...      N
# 883  A universal successor to a possessor may also ...      Y
# 884  A claim that a co-owner (A) holds against anot...      N
# 885  If the obligor of an alternative obligation ma...      Y
# 886  The manifestation of intention to cancel may n...      Y
#
#                                             hyp_tokens  hyp_length  \
# 0    ['a', 'special', 'provision', 'that', 'release...          39
# 1    ['there', 'is', 'a', 'limitation', 'period', '...          44
# 2    ['a', 'compulsory', 'auction', 'is', 'also', '...          20
# 3    ['in', 'cases', 'where', 'a', 'person', 'plans...          34
# 4    ['in', 'cases', 'where', 'an', 'individual', '...          45
# ..                                                 ...         ...
# 882  ['the', 'postponement', 'of', 'expiry', 'of', ...          31
# 883  ['a', 'universal', 'successor', 'to', 'a', 'po...          16
# 884  ['a', 'claim', 'that', 'a', 'co-owner', '(', '...          32
# 885  ['if', 'the', 'obligor', 'of', 'an', 'alternat...          38
# 886  ['the', 'manifestation', 'of', 'intention', 't...          11
#
#                                            prem_tokens  prem_length  overlap  \
# 0    ['article', '572', 'even', 'if', 'the', 'selle...           81       22
# 1    ['article', '565', 'the', 'provisions', 'of', ...          176       18
# 2    ['article', '568', '(', '1', ')', 'the', 'succ...          208       10
# 3    ['article', '697', '(', '1', ')', 'a', 'person...          111       15
# 4    ['article', '698', 'if', 'a', 'manager', 'enga...           59       16
# ..                                                 ...          ...      ...
# 882  ['article', '153', '(', '1', ')', 'the', 'post...           99       29
# 883  ['article', '187', '(', '1', ')', 'a', 'succes...           39       14
# 884  ['article', '254', 'a', 'claim', 'that', 'one'...           28       19
# 885  ['article', '406', 'if', 'the', 'subject', 'ma...           81       27
# 886  ['article', '540', '(', '1', ')', 'if', 'one',...           57       11
#
#      is_word_overlap negations  has_negation detected_subsequence  \
# 0               True   ['not']          True                  NaN
# 1               True    ['no']          True                  NaN
# 2               True        []         False                  NaN
# 3               True        []         False                  NaN
# 4               True   ['not']          True                  NaN
# ..               ...       ...           ...                  ...
# 882             True   ['not']          True                  NaN
# 883             True        []         False                  NaN
# 884             True   ['not']          True                  NaN
# 885             True   ['not']          True                  NaN
# 886             True   ['not']          True                  NaN
#
#      is_subsequence_heuristic instance_type
# 0                       False      original
# 1                       False      original
# 2                       False      original
# 3                       False      original
# 4                       False      original
# ..                        ...           ...
# 882                     False      original
# 883                     False      original
# 884                     False      original
# 885                     False      original
# 886                     False      original
#
# [887 rows x 16 columns]

# %%
cw_aug_df['instance_type'] = "cw adversarial"
wo_aug_df['instance_type'] = "wo adversarial"
aug_train_data_dict = {}
for year in years:
    # now get the dataset
    train_data = coliee_data_dict[year]
    print(f"Year : {year} : Original Train data: {train_data.shape[0]}")
    # augment cw data
    cw_aug_train_data = augment_train_data(coliee_data_dict[year], cw_aug_df, cw_aug_data_need_dict[year])
    print(f"CW Augmented train data: {cw_aug_train_data.shape[0]}")
    # assert
    assert cw_aug_data_need_dict[year] == (cw_aug_train_data.shape[0] - train_data.shape[0]) , "The data added is not matching for CW aug"

    # augment wo data
    wo_aug_train_data = augment_train_data(cw_aug_train_data, wo_aug_df, wo_aug_data_need_dict[year])
    print(f"WO + CW Augmented train data: {wo_aug_train_data.shape[0]}")
    # assert
    assert wo_aug_data_need_dict[year] == (wo_aug_train_data.shape[0] - cw_aug_train_data.shape[0]) , "The data added is not matching for WO aug"

    aug_train_data_dict[year] = wo_aug_train_data
# Out:
# Year : 2018 : Original Train data: 567
# CW Augmented train data: 579
# WO + CW Augmented train data: 618
# Year : 2019 : Original Train data: 625
# CW Augmented train data: 645
# WO + CW Augmented train data: 683
# Year : 2020 : Original Train data: 695
# CW Augmented train data: 718
# WO + CW Augmented train data: 760
# Year : 2021 : Original Train data: 806
# CW Augmented train data: 834
# WO + CW Augmented train data: 883
# Year : 2022 : Original Train data: 887
# CW Augmented train data: 916
# WO + CW Augmented train data: 955

# %%
aug_train_data_dict[2022]
# Out:
#                 id  label                                            premise  \
# 0          H18-1-1      1  Article 572\nEven if the seller makes a specia...
# 1          H18-1-2      0  Article 565\nThe provisions of the preceding t...
# 2          H18-1-3      0  Article 568\n(1) The successful bidder at an a...
# 3          H18-2-1      1  Article 697\n(1) A person that has begun to ma...
# 4          H18-2-2      1  Article 698\nIf a manager engages in benevolen...
# ..             ...    ...                                                ...
# 34   WO-AD-R01-9-U      0  Article 233\n(1) If a tree or bamboo branch fr...
# 35   WO-AD-R1-17-I      0  Article 450\n(1) If an obligor has the obligat...
# 36   WO-AD-R1-21-E      0  Article 518\n(1) To the extent of the amount o...
# 37  WO-AD-R01-36-I      0  Article 663\n(1) If the parties have not speci...
# 38  WO-AD-R01-37-A      0  Article 400\nIf the subject matter of a claim ...
#
#                                            hypothesis labels  \
# 0   A special provision that releases warranty can...      Y
# 1   There is a limitation period on pursuance of w...      N
# 2   A compulsory auction is also a sale, so warran...      N
# 3   In cases where a person plans to prevent crime...      Y
# 4   In cases where an individual rescues another p...      Y
# ..                                                ...    ...
# 34  If a tree or bamboo branch from a neighboring ...      N
# 35  A person who can act needs to be the guarantor...      N
# 36  To the extent of the amount of the obligation ...      N
# 37  If the depositor dies and the timing of the re...      N
# 38  In cases where the subject of a claim is the d...      N
#
#                                            hyp_tokens  hyp_length  \
# 0   ['a', 'special', 'provision', 'that', 'release...          39
# 1   ['there', 'is', 'a', 'limitation', 'period', '...          44
# 2   ['a', 'compulsory', 'auction', 'is', 'also', '...          20
# 3   ['in', 'cases', 'where', 'a', 'person', 'plans...          34
# 4   ['in', 'cases', 'where', 'an', 'individual', '...          45
# ..                                                ...         ...
# 34  [if, a, tree, or, bamboo, branch, from, a, nei...          28
# 35  [a, person, who, can, act, needs, to, be, the,...          20
# 36  [to, the, extent, of, the, amount, of, the, ob...          49
# 37  [if, the, depositor, dies, and, the, timing, o...          25
# 38  [in, cases, where, the, subject, of, a, claim,...          55
#
#                                           prem_tokens  prem_length  overlap  \
# 0   ['article', '572', 'even', 'if', 'the', 'selle...           81       22
# 1   ['article', '565', 'the', 'provisions', 'of', ...          176       18
# 2   ['article', '568', '(', '1', ')', 'the', 'succ...          208       10
# 3   ['article', '697', '(', '1', ')', 'a', 'person...          111       15
# 4   ['article', '698', 'if', 'a', 'manager', 'enga...           59       16
# ..                                                ...          ...      ...
# 34  [article, 233, (, 1, ), if, a, tree, or, bambo...           61       20
# 35  [article, 450, (, 1, ), if, an, obligor, has, ...          114       15
# 36  [article, 518, (, 1, ), to, the, extent, of, t...          137       39
# 37  [article, 663, (, 1, ), if, the, parties, have...           66       19
# 38  [article, 400, if, the, subject, matter, of, a...          178       43
#
#     is_word_overlap negations  has_negation detected_subsequence  \
# 0              True   ['not']          True                  NaN
# 1              True    ['no']          True                  NaN
# 2              True        []         False                  NaN
# 3              True        []         False                  NaN
# 4              True   ['not']          True                  NaN
# ..              ...       ...           ...                  ...
# 34             True        []         False
# 35             True        []         False
# 36             True        []         False
# 37             True        []         False
# 38             True        []         False
#
#     is_subsequence_heuristic   instance_type
# 0                      False        original
# 1                      False        original
# 2                      False        original
# 3                      False        original
# 4                      False        original
# ..                       ...             ...
# 34                     False  wo adversarial
# 35                     False  wo adversarial
# 36                     False  wo adversarial
# 37                     False  wo adversarial
# 38                     False  wo adversarial
#
# [955 rows x 16 columns]

# %%
for year in years:
    aug_train_data_file_path = f"/content/drive/MyDrive/data/task 4/train/coliee_aug_train_{year}.csv"
    aug_train_data_dict[year].to_csv(aug_train_data_file_path, index=False)

# %%
_,_, _ = get_cwb_artefacts_imbalance("after", years)
# Out:
# Year : 2018
# Number of total instances with contradiction : (300, 16)
# Number of entailment instances with contradiction : (150, 16)
# Number of non-entailment instances with contradiction : (150, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 0
# Year : 2019
# Number of total instances with contradiction : (344, 16)
# Number of entailment instances with contradiction : (172, 16)
# Number of non-entailment instances with contradiction : (172, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 0
# Year : 2020
# Number of total instances with contradiction : (388, 16)
# Number of entailment instances with contradiction : (194, 16)
# Number of non-entailment instances with contradiction : (194, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 0
# Year : 2021
# Number of total instances with contradiction : (446, 16)
# Number of entailment instances with contradiction : (223, 16)
# Number of non-entailment instances with contradiction : (223, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 0
# Year : 2022
# Number of total instances with contradiction : (494, 16)
# Number of entailment instances with contradiction : (247, 16)
# Number of non-entailment instances with contradiction : (247, 16)
# Difference in contradiction instances between non-entailment and entailment labels: 0

# %%
_ = get_wob_artefacts_imbalance(train_type="after", years=years)
# Out:
# [2018, 2019, 2020, 2021, 2022]
# 2018
# Year : 2018
# Number of total instances with Word Overlap : (316, 17)
# Number of entailment instances with Word Overlaps : (109, 17)
# Number of non-entailment instances with Word Overlaps : (109, 17)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 0
# 2019
# Year : 2019
# Number of total instances with Word Overlap : (336, 17)
# Number of entailment instances with Word Overlaps : (117, 17)
# Number of non-entailment instances with Word Overlaps : (117, 17)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 0
# 2020
# Year : 2020
# Number of total instances with Word Overlap : (369, 17)
# Number of entailment instances with Word Overlaps : (129, 17)
# Number of non-entailment instances with Word Overlaps : (129, 17)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 0
# 2021
# Year : 2021
# Number of total instances with Word Overlap : (433, 17)
# Number of entailment instances with Word Overlaps : (150, 17)
# Number of non-entailment instances with Word Overlaps : (150, 17)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 0
# 2022
# Year : 2022
# Number of total instances with Word Overlap : (453, 17)
# Number of entailment instances with Word Overlaps : (157, 17)
# Number of non-entailment instances with Word Overlaps : (157, 17)
# Difference in word overlap instances between entailment and non-entailment labels above 50%: 0

# %%
file_dict = {
            "train" : "/content/drive/MyDrive/data/task 4/train/coliee_aug_train_2018.csv",
        }

dataset = load_dataset(
    'csv',
    data_files=file_dict,
    delimiter=',',
    column_names=['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens','hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'detected_subsequence', 'is_subsequence_heuristic', 'instance_type'],
    skiprows=1
)

dataset = dataset.remove_columns('detected_subsequence')

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens', 'hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'is_subsequence_heuristic', 'instance_type'],
#         num_rows: 618
#     })
# })

# %%
datas = dataset['train'].train_test_split(test_size=0.1, seed=42)

datas
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens', 'hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'is_subsequence_heuristic', 'instance_type'],
#         num_rows: 556
#     })
#     test: Dataset({
#         features: ['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens', 'hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'is_subsequence_heuristic', 'instance_type'],
#         num_rows: 62
#     })
# })

# %%
datas['test']
# Out:
# Dataset({
#     features: ['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens', 'hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'is_subsequence_heuristic', 'instance_type'],
#     num_rows: 62
# })

# %%
data_type = "augmented"
if data_type == "normal":
    num_train = int(0.9 * len(dataset['train']))
    num_eval = len(dataset['train']) - num_train

    # Split the dataset
    train_datasets = dataset['train'].select(range(num_train))
    eval_datasets = dataset['train'].select(range(num_train, num_train + num_eval))
    test_datasets = dataset['test']

elif data_type == "augmented":
    data_split = dataset['train'].train_test_split(test_size=0.1, seed=42)

    # Split the dataset
    train_datasets = data_split['train']
    eval_datasets = data_split['test']
    test_datasets = dataset['test']

# %%
file_dict = {
            "test" : "/content/drive/MyDrive/data/task 4/test/adversarial_test_set/adversarial_test_set.csv"
        }

dataset = load_dataset(
    'csv',
    data_files=file_dict,
    delimiter=',',
    column_names=['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens','hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'detected_subsequence', 'is_subsequence_heuristic', 'Artefact Type', 'Adv Type'],
    skiprows=1
)

dataset = dataset.remove_columns('detected_subsequence')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
tmp_dataset = dataset.filter(lambda row: row['Artefact Type']=="Word Overlap")
# Out:
# Filter:   0%|          | 0/42 [00:00<?, ? examples/s]

# %%
tmp_dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['id', 'label', 'premise', 'hypothesis', 'labels', 'hyp_tokens', 'hyp_length', 'prem_tokens', 'prem_length', 'overlap', 'is_word_overlap', 'negations', 'has_negation', 'is_subsequence_heuristic', 'Artefact Type', 'Adv Type', '__index_level_0__'],
#         num_rows: 9
#     })
# })

# %%
dataset['test']['Artefact Type']
# Out:
# ['Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Word Overlap',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Contradiction Word',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Building)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (Y-Person)',
#  'Annotation Artefact (N - Rescind)',
#  'Annotation Artefact (N - Rescind)',
#  'Annotation Artefact (N - Rescind)',
#  'Annotation Artefact (N - Rescind)',
#  'Annotation Artefact (N - Rescind)',
#  'Annotation Artefact (N-Property)',
#  'Annotation Artefact (N-Property)',
#  'Annotation Artefact (N-Property)',
#  'Annotation Artefact (N-Property)',
#  'Annotation Artefact (N-Property)',
#  'Annotation Artefact (N-Property)']
